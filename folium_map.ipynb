# %%
# Import libraries
import pandas as pd
import folium

# %%
# Read in CSV
attendance_df = pd.read_csv("resources/attendance_and_locations.csv")

# %%
# Display the data
attendance_df.head()
# Out:
#   District name                    Category  \
# 0   Connecticut                         NaN
# 1   Connecticut                Homelessness
# 2   Connecticut  Students With Disabilities
# 3   Connecticut          Free/Reduced Lunch
# 4   Connecticut          Free/Reduced Lunch
#
#                         Student group  2021-2022 student count - year to date  \
# 0                        All Students                                  500285
# 1  Students Experiencing Homelessness                                    1814
# 2          Students With Disabilities                                   78417
# 3                  Free Meal Eligible                                  168984
# 4         Reduced Price Meal Eligible                                   29905
#
#    2021-2022 attendance rate - year to date  2020-2021 student count  \
# 0                                    0.9169                 496092.0
# 1                                    0.8348                   1735.0
# 2                                    0.8899                  76487.0
# 3                                    0.8851                 176225.0
# 4                                    0.9184                  30886.0
#
#    2020-2021 attendance rate  2019-2020 student count  \
# 0                     0.9294                 508346.0
# 1                     0.8155                   3916.0
# 2                     0.8946                  80365.0
# 3                     0.8861                 193706.0
# 4                     0.9299                  27507.0
#
#    2019-2020 attendance rate  Latitude  Longitude
# 0                     0.9479       NaN        NaN
# 1                     0.8884       NaN        NaN
# 2                     0.9277       NaN        NaN
# 3                     0.9314       NaN        NaN
# 4                     0.9518       NaN        NaN

# %%
# Remove state of Connecticut from District column
districts_df = attendance_df[(attendance_df['District name'] != 'Connecticut')]
districts_df.head(40)
# Out:
#                   District name                    Category  \
# 13      Andover School District                         NaN
# 14      Andover School District  Students With Disabilities
# 15      Andover School District          Free/Reduced Lunch
# 16      Andover School District              Race/Ethnicity
# 17      Andover School District                  High Needs
# 18      Andover School District                  High Needs
# 19      Ansonia School District                         NaN
# 20      Ansonia School District  Students With Disabilities
# 21      Ansonia School District          Free/Reduced Lunch
# 22      Ansonia School District          Free/Reduced Lunch
# 23      Ansonia School District          Free/Reduced Lunch
# 24      Ansonia School District            English Learners
# 25      Ansonia School District              Race/Ethnicity
# 26      Ansonia School District              Race/Ethnicity
# 27      Ansonia School District              Race/Ethnicity
# 28      Ansonia School District              Race/Ethnicity
# 29      Ansonia School District                  High Needs
# 30      Ansonia School District                  High Needs
# 31      Ashford School District                         NaN
# 32      Ashford School District  Students With Disabilities
# 33      Ashford School District          Free/Reduced Lunch
# 34      Ashford School District          Free/Reduced Lunch
# 35      Ashford School District          Free/Reduced Lunch
# 36      Ashford School District              Race/Ethnicity
# 37      Ashford School District              Race/Ethnicity
# 38      Ashford School District                  High Needs
# 39      Ashford School District                  High Needs
# 40         Avon School District                         NaN
# 41         Avon School District  Students With Disabilities
# 42         Avon School District          Free/Reduced Lunch
# 43         Avon School District          Free/Reduced Lunch
# 44         Avon School District          Free/Reduced Lunch
# 45         Avon School District            English Learners
# 46         Avon School District              Race/Ethnicity
# 47         Avon School District              Race/Ethnicity
# 48         Avon School District              Race/Ethnicity
# 49         Avon School District              Race/Ethnicity
# 50         Avon School District                  High Needs
# 51         Avon School District                  High Needs
# 52  Barkhamsted School District                         NaN
#
#                        Student group  2021-2022 student count - year to date  \
# 13                      All Students                                     161
# 14        Students With Disabilities                                      23
# 15  Free/Reduced Price Meal Eligible                                      30
# 16                             White                                     134
# 17       Students Without High Needs                                     113
# 18          Students With High Needs                                      48
# 19                      All Students                                    2139
# 20        Students With Disabilities                                     369
# 21                Free Meal Eligible                                    1192
# 22       Reduced Price Meal Eligible                                     225
# 23  Free/Reduced Price Meal Eligible                                    1417
# 24                  English Learners                                     122
# 25                   All other races                                     149
# 26         Black or African American                                     434
# 27       Hispanic/Latino of any race                                     987
# 28                             White                                     569
# 29       Students Without High Needs                                     528
# 30          Students With High Needs                                    1545
# 31                      All Students                                     343
# 32        Students With Disabilities                                      46
# 33                Free Meal Eligible                                      92
# 34       Reduced Price Meal Eligible                                      21
# 35  Free/Reduced Price Meal Eligible                                     113
# 36       Hispanic/Latino of any race                                      31
# 37                             White                                     283
# 38       Students Without High Needs                                     189
# 39          Students With High Needs                                     145
# 40                      All Students                                    3057
# 41        Students With Disabilities                                     324
# 42                Free Meal Eligible                                     226
# 43       Reduced Price Meal Eligible                                      60
# 44  Free/Reduced Price Meal Eligible                                     286
# 45                  English Learners                                      76
# 46                   All other races                                     712
# 47         Black or African American                                     179
# 48       Hispanic/Latino of any race                                     221
# 49                             White                                    1945
# 50       Students Without High Needs                                    2427
# 51          Students With High Needs                                     587
# 52                      All Students                                     199
#
#     2021-2022 attendance rate - year to date  2020-2021 student count  \
# 13                                    0.9386                    144.0
# 14                                    0.9315                      NaN
# 15                                    0.9274                     31.0
# 16                                    0.9365                    115.0
# 17                                    0.9410                    100.0
# 18                                    0.9328                     44.0
# 19                                    0.9045                   2153.0
# 20                                    0.8897                    394.0
# 21                                    0.8893                   1217.0
# 22                                    0.9282                    213.0
# 23                                    0.8953                   1430.0
# 24                                    0.9180                    119.0
# 25                                    0.9191                    166.0
# 26                                    0.8987                    421.0
# 27                                    0.8994                    946.0
# 28                                    0.9136                    620.0
# 29                                    0.9287                    551.0
# 30                                    0.8968                   1563.0
# 31                                    0.9309                    344.0
# 32                                    0.9253                     47.0
# 33                                    0.9167                     98.0
# 34                                    0.9174                     28.0
# 35                                    0.9168                    126.0
# 36                                    0.9133                     27.0
# 37                                    0.9349                    292.0
# 38                                    0.9385                    179.0
# 39                                    0.9206                    155.0
# 40                                    0.9457                   3093.0
# 41                                    0.9207                    305.0
# 42                                    0.9145                    184.0
# 43                                    0.9022                     51.0
# 44                                    0.9119                    235.0
# 45                                    0.9414                     90.0
# 46                                    0.9543                    737.0
# 47                                    0.9224                    172.0
# 48                                    0.9349                    226.0
# 49                                    0.9458                   1958.0
# 50                                    0.9517                   2501.0
# 51                                    0.9221                    546.0
# 52                                    0.9305                    193.0
#
#     2020-2021 attendance rate  2019-2020 student count  \
# 13                     0.9680                    158.0
# 14                        NaN                      NaN
# 15                     0.9414                     37.0
# 16                     0.9699                    128.0
# 17                     0.9752                    108.0
# 18                     0.9513                     50.0
# 19                     0.8923                   2185.0
# 20                     0.8692                    411.0
# 21                     0.8657                   1312.0
# 22                     0.9234                    147.0
# 23                     0.8743                   1459.0
# 24                     0.8951                    129.0
# 25                     0.9105                    170.0
# 26                     0.8693                    434.0
# 27                     0.8798                    923.0
# 28                     0.9217                    658.0
# 29                     0.9389                    587.0
# 30                     0.8764                   1598.0
# 31                     0.9550                    348.0
# 32                     0.9573                     56.0
# 33                     0.9281                      NaN
# 34                     0.9424                      NaN
# 35                     0.9312                    130.0
# 36                     0.9408                     22.0
# 37                     0.9598                    298.0
# 38                     0.9686                    182.0
# 39                     0.9380                    166.0
# 40                     0.9621                   3138.0
# 41                     0.9309                    330.0
# 42                     0.9152                    243.0
# 43                     0.9356                     47.0
# 44                     0.9197                    290.0
# 45                     0.9601                    104.0
# 46                     0.9760                    755.0
# 47                     0.9299                    162.0
# 48                     0.9414                    215.0
# 49                     0.9620                   2006.0
# 50                     0.9681                   2531.0
# 51                     0.9348                    607.0
# 52                     0.9698                    199.0
#
#     2019-2020 attendance rate   Latitude  Longitude
# 13                     0.9502  41.728585 -72.366582
# 14                        NaN  41.728585 -72.366582
# 15                     0.9401  41.728585 -72.366582
# 16                     0.9479  41.728585 -72.366582
# 17                     0.9552  41.728585 -72.366582
# 18                     0.9389  41.728585 -72.366582
# 19                     0.9413  41.341123 -73.084295
# 20                     0.9337  41.341123 -73.084295
# 21                     0.9312  41.341123 -73.084295
# 22                     0.9563  41.341123 -73.084295
# 23                     0.9338  41.341123 -73.084295
# 24                     0.9506  41.341123 -73.084295
# 25                     0.9451  41.341123 -73.084295
# 26                     0.9414  41.341123 -73.084295
# 27                     0.9366  41.341123 -73.084295
# 28                     0.9468  41.341123 -73.084295
# 29                     0.9568  41.341123 -73.084295
# 30                     0.9355  41.341123 -73.084295
# 31                     0.9585  41.892517 -72.169207
# 32                     0.9468  41.892517 -72.169207
# 33                        NaN  41.892517 -72.169207
# 34                        NaN  41.892517 -72.169207
# 35                     0.9477  41.892517 -72.169207
# 36                     0.9353  41.892517 -72.169207
# 37                     0.9607  41.892517 -72.169207
# 38                     0.9666  41.892517 -72.169207
# 39                     0.9496  41.892517 -72.169207
# 40                     0.9583  41.792744 -72.889560
# 41                     0.9421  41.792744 -72.889560
# 42                     0.9389  41.792744 -72.889560
# 43                     0.9365  41.792744 -72.889560
# 44                     0.9385  41.792744 -72.889560
# 45                     0.9435  41.792744 -72.889560
# 46                     0.9643  41.792744 -72.889560
# 47                     0.9478  41.792744 -72.889560
# 48                     0.9520  41.792744 -72.889560
# 49                     0.9576  41.792744 -72.889560
# 50                     0.9622  41.792744 -72.889560
# 51                     0.9417  41.792744 -72.889560
# 52                     0.9573  41.910804 -72.989810

# %%
# Normalize the student count for dot size scaling
min_radius = 5  # Minimum size for a dot
max_radius = 15  # Maximum size for a dot
student_counts = districts_df['2021-2022 student count - year to date']
scaled_sizes = ((student_counts - student_counts.min()) / (student_counts.max() - student_counts.min())) * (max_radius - min_radius) + min_radius

# Reset indices to ensure they match
districts_df = districts_df.reset_index(drop=True)
scaled_sizes = scaled_sizes.reset_index(drop=True)

# %%
# Calculate the center of the map
center_lat = districts_df['Latitude'].mean()
center_lon = districts_df['Longitude'].mean()

# Initialize the map
m = folium.Map(location=[center_lat, center_lon], zoom_start=9)

# %%
# Define color based on attendance rate with custom ranges
def get_color(attendance_rate):
    if attendance_rate < 90:
        return 'red'  # Below 90%
    elif attendance_rate <= 91:
        return 'orange'  # Up to 91%
    elif attendance_rate <= 92:
        return 'yellow'  # Up to 92%
    elif attendance_rate <= 93:
        return 'lightgreen'  # Up to 93%
    elif attendance_rate <= 94:
        return 'green'  # Up to 94%
    else:
        return 'darkgreen'  # More than 94%

# %%
# Create FeatureGroups for each student group
all_students_group = folium.FeatureGroup(name='All Students')
high_needs_group = folium.FeatureGroup(name='Students With High Needs')
without_high_needs_group = folium.FeatureGroup(name='Students Without High Needs')

# %%
# Add markers for "All Students"
for index, row in districts_df[districts_df['Student group'] == 'All Students'].iterrows():
    district_name = row['District name']
    attendance_rate = row['2021-2022 attendance rate - year to date'] * 100  # Convert to percentage
    latitude = row['Latitude']
    longitude = row['Longitude']
    student_count = row['2021-2022 student count - year to date']
    
    # Ensure we have a matching size for the dot
    dot_size = scaled_sizes.iloc[index] if index in scaled_sizes.index else 5  # Default size if mismatch
    
    # Get the color based on attendance rate
    dot_color = get_color(attendance_rate)
    
    tooltip_text = f"District: {district_name}<br>Attendance Rate: {attendance_rate}%"

    folium.CircleMarker(
        location=[latitude, longitude],
        radius=dot_size,  # Adjust size of the dot
        color=dot_color,  # Border color
        fill=True,
        fill_color=dot_color,  # Fill color
        fill_opacity=0.7,
        tooltip=tooltip_text
    ).add_to(all_students_group)

# %%
# Add markers for "Students With High Needs"
for index, row in districts_df[districts_df['Student group'] == 'Students With High Needs'].iterrows():
    district_name = row['District name']
    attendance_rate = row['2021-2022 attendance rate - year to date'] * 100  # Convert to percentage
    latitude = row['Latitude']
    longitude = row['Longitude']
    student_count = row['2021-2022 student count - year to date']
    
    # Ensure we have a matching size for the dot
    dot_size = scaled_sizes.iloc[index] if index in scaled_sizes.index else 5  # Default size if mismatch
    
    # Get the color based on attendance rate
    dot_color = get_color(attendance_rate)
    
    tooltip_text = f"District: {district_name}<br>Attendance Rate: {attendance_rate}%"

    folium.CircleMarker(
        location=[latitude, longitude],
        radius=dot_size,  # Adjust size of the dot
        color=dot_color,  # Border color
        fill=True,
        fill_color=dot_color,  # Fill color
        fill_opacity=0.7,
        tooltip=tooltip_text
    ).add_to(high_needs_group)

# %%
# Add markers for "Students Without High Needs" (all districts where the student group is not "Students With High Needs")
for index, row in districts_df[districts_df['Student group'] != 'Students With High Needs'].iterrows():
    district_name = row['District name']
    attendance_rate = row['2021-2022 attendance rate - year to date'] * 100  # Convert to percentage
    latitude = row['Latitude']
    longitude = row['Longitude']
    student_count = row['2021-2022 student count - year to date']
    
    # Ensure we have a matching size for the dot
    dot_size = scaled_sizes.iloc[index] if index in scaled_sizes.index else 5  # Default size if mismatch
    
    # Get the color based on attendance rate
    dot_color = get_color(attendance_rate)
    
    tooltip_text = f"District: {district_name}<br>Attendance Rate: {attendance_rate}%"

    folium.CircleMarker(
        location=[latitude, longitude],
        radius=dot_size,  # Adjust size of the dot
        color=dot_color,  # Border color
        fill=True,
        fill_color=dot_color,  # Fill color
        fill_opacity=0.7,
        tooltip=tooltip_text
    ).add_to(without_high_needs_group)

# %%
# Add the feature groups to the map
all_students_group.add_to(m)
high_needs_group.add_to(m)
without_high_needs_group.add_to(m)

# Add a layer control to toggle between the groups
folium.LayerControl().add_to(m)

# %%
# Save and display the map
m.save('interactive_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bd4eb91da998e1646abce7cd279d1a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bd4eb91da998e1646abce7cd279d1a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5bd4eb91da998e1646abce7cd279d1a2 = L.map(
#                 &quot;map_5bd4eb91da998e1646abce7cd279d1a2&quot;,
#                 {
#                     center: [41.552396898063314, -72.75407246118695],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fb9faeea478933ed3b806cddf418714 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fb9faeea478933ed3b806cddf418714.addTo(map_5bd4eb91da998e1646abce7cd279d1a2);
#
#
#             var feature_group_eec6ae02a4c461393223029bd686adc9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_0ffed1e4e8d684159a52d20df17e4159 = L.circleMarker(
#                 [41.728584995, -72.366581965],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.076373090672734, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_eec6ae02a4c461393223029bd686adc9);
#
#
#             circle_marker_0ffed1e4e8d684159a52d20df17e4159.bindTooltip(
#                 `&lt;div&gt;
#                      District: Andover School District&lt;br&gt;Attendance Rate: 93.86%
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_501d5cb8422c0c734fb34807f68f9dd1 = L.circleMarker(
#                 [41.341123013, -73.084294998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.147762972592352, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_eec6ae02a4c461393223029bd686adc9);
#
#
#             circle_marker_501d5cb8422c0c734fb34807f68f9dd1.bindTooltip(
#                 `&lt;div&gt;
#                      District: Ansonia School District&lt;br&gt;Attendance Rate: 90.45%
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_2e46a9418028e30e343a93221b9d69e0 = L.circleMarker(
#                 [41.892517, -72.169207005],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.1749539594843466, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_eec6ae02a4c461393223029bd686adc9);
#
#
#             circle_marker_2e46a9418028e30e343a93221b9d69e0.bindTooltip(
#                 `&lt;div&gt;
#                      District: Ashford School District&lt;br&gt;Attendance Rate: 93.08999999999999%
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a12672789710fb78666f3b8d5289ccb5 = L.circleMarker(
#                 [41.79274398, -72.889560001],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.6450005416531255, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_eec6ae02a4c461393223029bd686adc9);
#
#
#             circle_marker_a12672789710fb78666f3b8d5289ccb5.bindTooltip(
#                 `&lt;div&gt;
#                      District: Avon School District&lt;br&gt;Attendance Rate: 94.57%
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: tr
