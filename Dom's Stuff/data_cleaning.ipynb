# %%
# Import libraries 
import pandas as pd
import pprint as ppr
import matplotlib as pyplot
import pydeck as pdy
import numpy as np
import scipy. stats as st
import warnings 
warnings.filterwarnings("ignore")

# %%
# Define input data (previously imported from PostgreSQL)
locations_table_csv = "resources/locations_table.csv"
attendance_table_csv = "resources/attendance_table.csv"

# %%
# Read in the data sets
locations_df = pd.read_csv(locations_table_csv, low_memory= False)
attendance_df = pd.read_csv(attendance_table_csv, low_memory = False)

# %%
# Display Locations data
locations_df.head()
# Out:
#                  District Name                School Name Organization Type  \
# 0   Litchfield School District              Center School    Public Schools
# 1      Norwalk School District  Brien McMahon High School    Public Schools
# 2    Waterbury School District         H. S. Chase School    Public Schools
# 3   Bridgeport School District   Jettie S. Tisdale School    Public Schools
# 4  Regional School District 06       Goshen Center School  Regional Schools
#
#    Organization Code               Address        Town     Zipcode  \
# 0             740211           125 West St  Litchfield       06759
# 1            1036211   300 Highland Avenue     Norwalk       06854
# 2            1510711       40 Woodtick Rd.   Waterbury  06705-2207
# 3             152211  250 Hollister Avenue  Bridgeport       06607
# 4            2060112          50 North St.      Goshen  06756-1509
#
#           Phone  PreKindergarten  Kindergarten  ...  Grade 6  Grade 7  \
# 0  860-567-7510                1             1  ...        0        0
# 1  203-852-9488                0             0  ...        0        0
# 2  203-574-8188                1             1  ...        0        0
# 3  203-576-8037                1             1  ...        1        1
# 4  860-491-6020                1             1  ...        0        0
#
#    Grade 8  Grade 9  Grade 10  Grade 11  Grade 12        Student Open Date  \
# 0        0        0         0         0         0  1984-07-01T00:00:00.000
# 1        0        1         1         1         1  1984-07-01T00:00:00.000
# 2        0        0         0         0         0  1984-07-01T00:00:00.000
# 3        1        0         0         0         0  1984-07-01T00:00:00.000
# 4        0        0         0         0         0  2002-07-01T00:00:00.000
#
#    Interdistrict Magnet                                           Location
# 0                   0.0  125 West St\nLitchfield, CT 06759\n(41.7457940...
# 1                   0.0  300 Highland Avenue\nNorwalk, CT 06854\n(41.08...
# 2                   0.0  40 Woodtick Rd.\nWaterbury, CT 06705-2207\n(41...
# 3                   0.0  250 Hollister Avenue\nBridgeport, CT 06607\n(4...
# 4                   0.0  50 North St.\nGoshen, CT 06756-1509\n(41.83492...
#
# [5 rows x 25 columns]

# %%
# Filter Locations to specific columns
columns_to_keep = ["District Name", "School Name", "Organization Type", "Location"]
locations_filtered_df = locations_df[columns_to_keep]
locations_filtered_df.head()
# Out:
#                  District Name                School Name Organization Type  \
# 0   Litchfield School District              Center School    Public Schools
# 1      Norwalk School District  Brien McMahon High School    Public Schools
# 2    Waterbury School District         H. S. Chase School    Public Schools
# 3   Bridgeport School District   Jettie S. Tisdale School    Public Schools
# 4  Regional School District 06       Goshen Center School  Regional Schools
#
#                                             Location
# 0  125 West St\nLitchfield, CT 06759\n(41.7457940...
# 1  300 Highland Avenue\nNorwalk, CT 06854\n(41.08...
# 2  40 Woodtick Rd.\nWaterbury, CT 06705-2207\n(41...
# 3  250 Hollister Avenue\nBridgeport, CT 06607\n(4...
# 4  50 North St.\nGoshen, CT 06756-1509\n(41.83492...

# %%
# Separate "Location" column
locations_filtered_df[["Street", "City", "Coordinates"]] = locations_filtered_df["Location"].str.split('\n', n=2, expand=True)
locations_filtered_df.head()
# Out:
#                  District Name                School Name Organization Type  \
# 0   Litchfield School District              Center School    Public Schools
# 1      Norwalk School District  Brien McMahon High School    Public Schools
# 2    Waterbury School District         H. S. Chase School    Public Schools
# 3   Bridgeport School District   Jettie S. Tisdale School    Public Schools
# 4  Regional School District 06       Goshen Center School  Regional Schools
#
#                                             Location                Street  \
# 0  125 West St\nLitchfield, CT 06759\n(41.7457940...           125 West St
# 1  300 Highland Avenue\nNorwalk, CT 06854\n(41.08...   300 Highland Avenue
# 2  40 Woodtick Rd.\nWaterbury, CT 06705-2207\n(41...       40 Woodtick Rd.
# 3  250 Hollister Avenue\nBridgeport, CT 06607\n(4...  250 Hollister Avenue
# 4  50 North St.\nGoshen, CT 06756-1509\n(41.83492...          50 North St.
#
#                        City                    Coordinates
# 0      Litchfield, CT 06759  (41.745794007, -73.194830005)
# 1         Norwalk, CT 06854  (41.085690004, -73.433214013)
# 2  Waterbury, CT 06705-2207  (41.552633006, -73.005926969)
# 3      Bridgeport, CT 06607   (41.17816201, -73.160356997)
# 4     Goshen, CT 06756-1509   (41.83492398, -73.226575038)

# %%
# Create "Latitude" and "Longitude columns
locations_filtered_df[["Latitude", "Longitude"]] = locations_filtered_df["Coordinates"].str.extract(r'\(([^,]+), ([^,]+)\)')
locations_filtered_df.head()
# Out:
#                  District Name                School Name Organization Type  \
# 0   Litchfield School District              Center School    Public Schools
# 1      Norwalk School District  Brien McMahon High School    Public Schools
# 2    Waterbury School District         H. S. Chase School    Public Schools
# 3   Bridgeport School District   Jettie S. Tisdale School    Public Schools
# 4  Regional School District 06       Goshen Center School  Regional Schools
#
#                                             Location                Street  \
# 0  125 West St\nLitchfield, CT 06759\n(41.7457940...           125 West St
# 1  300 Highland Avenue\nNorwalk, CT 06854\n(41.08...   300 Highland Avenue
# 2  40 Woodtick Rd.\nWaterbury, CT 06705-2207\n(41...       40 Woodtick Rd.
# 3  250 Hollister Avenue\nBridgeport, CT 06607\n(4...  250 Hollister Avenue
# 4  50 North St.\nGoshen, CT 06756-1509\n(41.83492...          50 North St.
#
#                        City                    Coordinates      Latitude  \
# 0      Litchfield, CT 06759  (41.745794007, -73.194830005)  41.745794007
# 1         Norwalk, CT 06854  (41.085690004, -73.433214013)  41.085690004
# 2  Waterbury, CT 06705-2207  (41.552633006, -73.005926969)  41.552633006
# 3      Bridgeport, CT 06607   (41.17816201, -73.160356997)   41.17816201
# 4     Goshen, CT 06756-1509   (41.83492398, -73.226575038)   41.83492398
#
#        Longitude
# 0  -73.194830005
# 1  -73.433214013
# 2  -73.005926969
# 3  -73.160356997
# 4  -73.226575038

# %%
# Drop unnecessary columns
drop_columns = ["Location", "Coordinates"]
locations_filtered_df = locations_filtered_df.drop(columns = drop_columns)
locations_filtered_df.head()
# Out:
#                  District Name                School Name Organization Type  \
# 0   Litchfield School District              Center School    Public Schools
# 1      Norwalk School District  Brien McMahon High School    Public Schools
# 2    Waterbury School District         H. S. Chase School    Public Schools
# 3   Bridgeport School District   Jettie S. Tisdale School    Public Schools
# 4  Regional School District 06       Goshen Center School  Regional Schools
#
#                  Street                      City      Latitude      Longitude
# 0           125 West St      Litchfield, CT 06759  41.745794007  -73.194830005
# 1   300 Highland Avenue         Norwalk, CT 06854  41.085690004  -73.433214013
# 2       40 Woodtick Rd.  Waterbury, CT 06705-2207  41.552633006  -73.005926969
# 3  250 Hollister Avenue      Bridgeport, CT 06607   41.17816201  -73.160356997
# 4          50 North St.     Goshen, CT 06756-1509   41.83492398  -73.226575038

# %%
# Convert lat/lon to numeric
locations_filtered_df["Latitude"] = pd.to_numeric(locations_filtered_df["Latitude"])
locations_filtered_df["Longitude"] = pd.to_numeric(locations_filtered_df["Longitude"])
locations_filtered_df.dtypes
# Out:
# District Name         object
# School Name           object
# Organization Type     object
# Street                object
# City                  object
# Latitude             float64
# Longitude            float64
# dtype: object

# %%
locations_filtered_df.nunique()
# Out:
# District Name         206
# School Name          1218
# Organization Type      16
# Street               1175
# City                  861
# Latitude             1103
# Longitude            1103
# dtype: int64

# %%
# Create DataFrame with district name and coordinates
district_coordinates_df = locations_filtered_df[["District Name", "Latitude", "Longitude"]]
district_coordinates_df.head()
# Out:
#                  District Name   Latitude  Longitude
# 0   Litchfield School District  41.745794 -73.194830
# 1      Norwalk School District  41.085690 -73.433214
# 2    Waterbury School District  41.552633 -73.005927
# 3   Bridgeport School District  41.178162 -73.160357
# 4  Regional School District 06  41.834924 -73.226575

# %%
# Keep only one set of coordinates per district
district_coordinates_filtered_df = district_coordinates_df.drop_duplicates(subset = "District Name", keep = "first")
district_coordinates_filtered_df.head()
# Out:
#                  District Name   Latitude  Longitude
# 0   Litchfield School District  41.745794 -73.194830
# 1      Norwalk School District  41.085690 -73.433214
# 2    Waterbury School District  41.552633 -73.005927
# 3   Bridgeport School District  41.178162 -73.160357
# 4  Regional School District 06  41.834924 -73.226575

# %%
district_coordinates_filtered_df.nunique()
# Out:
# District Name    206
# Latitude         204
# Longitude        204
# dtype: int64

# %%
# Rename District Name column to match other CSV
district_coordinates_filtered_df=district_coordinates_filtered_df.rename(columns={"District Name":"District name"})
district_coordinates_filtered_df.head()
# Out:
#                  District name   Latitude  Longitude
# 0   Litchfield School District  41.745794 -73.194830
# 1      Norwalk School District  41.085690 -73.433214
# 2    Waterbury School District  41.552633 -73.005927
# 3   Bridgeport School District  41.178162 -73.160357
# 4  Regional School District 06  41.834924 -73.226575

# %%
# Display Attendance data
attendance_df.head()
# Out:
#   District code District name                    Category  \
# 0       00000CT   Connecticut                         NaN
# 1       00000CT   Connecticut                Homelessness
# 2       00000CT   Connecticut  Students With Disabilities
# 3       00000CT   Connecticut          Free/Reduced Lunch
# 4       00000CT   Connecticut          Free/Reduced Lunch
#
#                         Student group  2021-2022 student count - year to date  \
# 0                        All Students                                  500285
# 1  Students Experiencing Homelessness                                    1814
# 2          Students With Disabilities                                   78417
# 3                  Free Meal Eligible                                  168984
# 4         Reduced Price Meal Eligible                                   29905
#
#    2021-2022 attendance rate - year to date  2020-2021 student count  \
# 0                                    0.9169                 496092.0
# 1                                    0.8348                   1735.0
# 2                                    0.8899                  76487.0
# 3                                    0.8851                 176225.0
# 4                                    0.9184                  30886.0
#
#    2020-2021 attendance rate  2019-2020 student count  \
# 0                     0.9294                 508346.0
# 1                     0.8155                   3916.0
# 2                     0.8946                  80365.0
# 3                     0.8861                 193706.0
# 4                     0.9299                  27507.0
#
#    2019-2020 attendance rate Reporting period Date update
# 0                     0.9479        June 2022  2022-07-22
# 1                     0.8884        June 2022  2022-07-22
# 2                     0.9277        June 2022  2022-07-22
# 3                     0.9314        June 2022  2022-07-22
# 4                     0.9518        June 2022  2022-07-22

# %%
# Drop unnecessary columns from Attendance
drop_columns_2 = ["District code", "Reporting period", "Date update"]
attendance_filtered_df = attendance_df.drop(columns = drop_columns_2)
attendance_filtered_df.head()
# Out:
#   District name                    Category  \
# 0   Connecticut                         NaN
# 1   Connecticut                Homelessness
# 2   Connecticut  Students With Disabilities
# 3   Connecticut          Free/Reduced Lunch
# 4   Connecticut          Free/Reduced Lunch
#
#                         Student group  2021-2022 student count - year to date  \
# 0                        All Students                                  500285
# 1  Students Experiencing Homelessness                                    1814
# 2          Students With Disabilities                                   78417
# 3                  Free Meal Eligible                                  168984
# 4         Reduced Price Meal Eligible                                   29905
#
#    2021-2022 attendance rate - year to date  2020-2021 student count  \
# 0                                    0.9169                 496092.0
# 1                                    0.8348                   1735.0
# 2                                    0.8899                  76487.0
# 3                                    0.8851                 176225.0
# 4                                    0.9184                  30886.0
#
#    2020-2021 attendance rate  2019-2020 student count  \
# 0                     0.9294                 508346.0
# 1                     0.8155                   3916.0
# 2                     0.8946                  80365.0
# 3                     0.8861                 193706.0
# 4                     0.9299                  27507.0
#
#    2019-2020 attendance rate
# 0                     0.9479
# 1                     0.8884
# 2                     0.9277
# 3                     0.9314
# 4                     0.9518

# %%
# Merge Locations and Attendance DataFrames
attendance_merged_df = pd.merge(attendance_filtered_df, district_coordinates_filtered_df, on = 'District name', how = "left")
attendance_merged_df.head(25)
# Out:
#               District name                    Category  \
# 0               Connecticut                         NaN
# 1               Connecticut                Homelessness
# 2               Connecticut  Students With Disabilities
# 3               Connecticut          Free/Reduced Lunch
# 4               Connecticut          Free/Reduced Lunch
# 5               Connecticut          Free/Reduced Lunch
# 6               Connecticut            English Learners
# 7               Connecticut              Race/Ethnicity
# 8               Connecticut              Race/Ethnicity
# 9               Connecticut              Race/Ethnicity
# 10              Connecticut              Race/Ethnicity
# 11              Connecticut                  High Needs
# 12              Connecticut                  High Needs
# 13  Andover School District                         NaN
# 14  Andover School District  Students With Disabilities
# 15  Andover School District          Free/Reduced Lunch
# 16  Andover School District              Race/Ethnicity
# 17  Andover School District                  High Needs
# 18  Andover School District                  High Needs
# 19  Ansonia School District                         NaN
# 20  Ansonia School District  Students With Disabilities
# 21  Ansonia School District          Free/Reduced Lunch
# 22  Ansonia School District          Free/Reduced Lunch
# 23  Ansonia School District          Free/Reduced Lunch
# 24  Ansonia School District            English Learners
#
#                          Student group  \
# 0                         All Students
# 1   Students Experiencing Homelessness
# 2           Students With Disabilities
# 3                   Free Meal Eligible
# 4          Reduced Price Meal Eligible
# 5     Free/Reduced Price Meal Eligible
# 6                     English Learners
# 7                      All other races
# 8            Black or African American
# 9          Hispanic/Latino of any race
# 10                               White
# 11         Students Without High Needs
# 12            Students With High Needs
# 13                        All Students
# 14          Students With Disabilities
# 15    Free/Reduced Price Meal Eligible
# 16                               White
# 17         Students Without High Needs
# 18            Students With High Needs
# 19                        All Students
# 20          Students With Disabilities
# 21                  Free Meal Eligible
# 22         Reduced Price Meal Eligible
# 23    Free/Reduced Price Meal Eligible
# 24                    English Learners
#
#     2021-2022 student count - year to date  \
# 0                                   500285
# 1                                     1814
# 2                                    78417
# 3                                   168984
# 4                                    29905
# 5                                   198889
# 6                                    43571
# 7                                    48700
# 8                                    63099
# 9                                   146298
# 10                                  242188
# 11                                  241106
# 12                                  248239
# 13                                     161
# 14                                      23
# 15                                      30
# 16                                     134
# 17                                     113
# 18                                      48
# 19                                    2139
# 20                                     369
# 21                                    1192
# 22                                     225
# 23                                    1417
# 24                                     122
#
#     2021-2022 attendance rate - year to date  2020-2021 student count  \
# 0                                     0.9169                 496092.0
# 1                                     0.8348                   1735.0
# 2                                     0.8899                  76487.0
# 3                                     0.8851                 176225.0
# 4                                     0.9184                  30886.0
# 5                                     0.8901                 207111.0
# 6                                     0.8976                  40619.0
# 7                                     0.9314                  47339.0
# 8                                     0.8941                  62267.0
# 9                                     0.8935                 138260.0
# 10                                    0.9338                 248226.0
# 11                                    0.9398                 236395.0
# 12                                    0.8954                 251220.0
# 13                                    0.9386                    144.0
# 14                                    0.9315                      NaN
# 15                                    0.9274                     31.0
# 16                                    0.9365                    115.0
# 17                                    0.9410                    100.0
# 18                                    0.9328                     44.0
# 19                                    0.9045                   2153.0
# 20                                    0.8897                    394.0
# 21                                    0.8893                   1217.0
# 22                                    0.9282                    213.0
# 23                                    0.8953                   1430.0
# 24                                    0.9180                    119.0
#
#     2020-2021 attendance rate  2019-2020 student count  \
# 0                      0.9294                 508346.0
# 1                      0.8155                   3916.0
# 2                      0.8946                  80365.0
# 3                      0.8861                 193706.0
# 4                      0.9299                  27507.0
# 5                      0.8927                 221213.0
# 6                      0.8948                  45413.0
# 7                      0.9483                  47260.0
# 8                      0.8931                  64200.0
# 9                      0.8975                 136953.0
# 10                     0.9523                 259933.0
# 11                     0.9616                 241610.0
# 12                     0.8996                 266736.0
# 13                     0.9680                    158.0
# 14                        NaN                      NaN
# 15                     0.9414                     37.0
# 16                     0.9699                    128.0
# 17                     0.9752                    108.0
# 18                     0.9513                     50.0
# 19                     0.8923                   2185.0
# 20                     0.8692                    411.0
# 21                     0.8657                   1312.0
# 22                     0.9234                    147.0
# 23                     0.8743                   1459.0
# 24                     0.8951                    129.0
#
#     2019-2020 attendance rate   Latitude  Longitude
# 0                      0.9479        NaN        NaN
# 1                      0.8884        NaN        NaN
# 2                      0.9277        NaN        NaN
# 3                      0.9314        NaN        NaN
# 4                      0.9518        NaN        NaN
# 5                      0.9340        NaN        NaN
# 6                      0.9389        NaN        NaN
# 7                      0.9559        NaN        NaN
# 8                      0.9401        NaN        NaN
# 9                      0.9362        NaN        NaN
# 10                     0.9543        NaN        NaN
# 11                     0.9606        NaN        NaN
# 12                     0.9361        NaN        NaN
# 13                     0.9502  41.728585 -72.366582
# 14                        NaN  41.728585 -72.366582
# 15                     0.9401  41.728585 -72.366582
# 16                     0.9479  41.728585 -72.366582
# 17                     0.9552  41.728585 -72.366582
# 18                     0.9389  41.728585 -72.366582
# 19                     0.9413  41.341123 -73.084295
# 20                     0.9337  41.341123 -73.084295
# 21                     0.9312  41.341123 -73.084295
# 22                     0.9563  41.341123 -73.084295
# 23                     0.9338  41.341123 -73.084295
# 24                     0.9506  41.341123 -73.084295

# %%
attendance_merged_df.nunique()
# Out:
# District name                                201
# Category                                       6
# Student group                                 13
# 2021-2022 student count - year to date      1096
# 2021-2022 attendance rate - year to date     845
# 2020-2021 student count                     1104
# 2020-2021 attendance rate                    980
# 2019-2020 student count                     1114
# 2019-2020 attendance rate                    557
# Latitude                                     198
# Longitude                                    198
# dtype: int64

# %%
# Overall -- there are 200 school districts, and 2 of them do no have coordinates listed

# %%
attendance_merged_df.to_csv("resources/attendance_and_locations.csv", index=False)
